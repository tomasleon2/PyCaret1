# %%
import pandas as pd
from pycaret.classification import *

# %%
data = pd.read_csv("C:/Users/lordv/Downloads/german.data",sep=" ")
data
# Out:
#     Status of existing checking account  Duration in month Credit history  \
# 0                                   A11                  6            A34
# 1                                   A12                 48            A32
# 2                                   A14                 12            A34
# 3                                   A11                 42            A32
# 4                                   A11                 24            A33
# ..                                  ...                ...            ...
# 995                                 A14                 12            A32
# 996                                 A11                 30            A32
# 997                                 A14                 12            A32
# 998                                 A11                 45            A32
# 999                                 A12                 45            A34
#
#     Purpose  Credit amount Savings account/bonds Present employment since  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Status of existing checking account                       1000 non-null   object
#  1   Duration in month                                         1000 non-null   int64
#  2   Credit history                                            1000 non-null   object
#  3   Purpose                                                   1000 non-null   object
#  4   Credit amount                                             1000 non-null   int64
#  5   Savings account/bonds                                     1000 non-null   object
#  6   Present employment since                                  1000 non-null   object
#  7   Installment rate in percentage of disposable income       1000 non-null   int64
# ...

# %%
FirstModel = setup(data, target = 'GB Flag', session_id=1234)
# Out:
# <style  type="text/css" >
# #T_e67b446c_6832_11ec_8e7f_5cbaefab109arow44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_e67b446c_6832_11ec_8e7f_5cbaefab109a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e67b446c_6832_11ec_8e7f_5cbaefab109alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e67b446c_6832_11ec_8e7f_5cbaefab109arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e67b446c_6832_11ec_8e7f_5cbaefab109arow0_col1" class="data row0 col1" >1234</td>
#             </tr>
#             <tr>
#                         <th id="T_e67b446c_6832_11ec_8e7f_5cbaefab109alevel0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models(sort = 'AUC')
# Out:
# <style  type="text/css" >
#     #T_9edac98c_6757_11ec_8918_5cbaefab109a th {
#           text-align: left;
# ...

# %%
Cat = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col0,#T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col1,#T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col2,#T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col3,#T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col4,#T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col5,#T_0e22912e_6758_11ec_885b_5cbaefab109arow10_col6{
#             background:  yellow;
#         }</style><table id="T_0e22912e_6758_11ec_885b_5cbaefab109a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_Cat = tune_model(Cat, optimize = 'AUC')
# Out:
# <style  type="text/css" >
# #T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col0,#T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col1,#T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col2,#T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col3,#T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col4,#T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col5,#T_7de7e37e_6758_11ec_9fd2_5cbaefab109arow10_col6{
#             background:  yellow;
#         }</style><table id="T_7de7e37e_6758_11ec_9fd2_5cbaefab109a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(tuned_Cat, plot='feature')

# %%
evaluate_model(tuned_Cat)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(tuned_Cat)
# Out:
# <style  type="text/css" >
# </style><table id="T_e8f17018_6758_11ec_97ac_5cbaefab109a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8f17018_6758_11ec_97ac_5cbaefab109alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e8f17018_6758_11ec_97ac_5cbaefab109arow0_col0" class="data row0 col0" >CatBoost Classifier</td>
# ...

# %%
final_Cat = finalize_model(tuned_Cat)

# %%
print(final_Cat)

# %%
predict_model(final_Cat)
# Out:
# <style  type="text/css" >
# </style><table id="T_425b4c80_6759_11ec_9c8e_5cbaefab109a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_425b4c80_6759_11ec_9c8e_5cbaefab109alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_425b4c80_6759_11ec_9c8e_5cbaefab109arow0_col0" class="data row0 col0" >CatBoost Classifier</td>
# ...
